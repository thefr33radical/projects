# %% [markdown]
# **Sigmoid Function :**
#
# The main reason why we use sigmoid function is because it exists between (0 to 1). Therefore, it is especially used for models where we have to predict the probability as an output.
# Since probability of anything exists only between the range of 0 and 1, sigmoid is the right choice.
#
# **Example Scenarios :**<br>
# Is your favorite football team going to win the match today? — yes/no (0/1)<br>
# Does a student pass in exam? — yes/no (0/1)
#
#
# The logistic function is given by: <br>
# **F(x) = L / ( 1 + a.e^-k.(x-x0) )**
#
# where<br>
# L – Curve’s maximum value<br>
# k – Steepness of the curve<br>
# x0 – x value of Sigmoid’s midpoint<br>
#
# A standard logistic function is called sigmoid function (k=1,x0=0,L=1)<br>
# **S(x) = 1 / ( 1 + e^-(x) )**

# %%
from IPython.display import Image
import os

Image(filename=os.getcwd()+'/images/sigmoid_eq.png')
# Sigmoid Function

# %%
Image(filename=os.getcwd()+'/images/sigmoid.png')
# Sigmoid Curve

# %% [markdown]
# **Let us vary the parameters L,a,k in F(x) = L / ( 1 + a.e^-k.(x-x0) )**

# %%
Image(filename=os.getcwd()+'/images/sigomid_eq_default.png')
# Default Sigmoid Curve

# %%
Image(filename=os.getcwd()+'/images/sigomid_eq_l6.png')
# Sigmoid Curve when L=6.

# %%
Image(filename=os.getcwd()+'/images/sigomid_eq_k50.png')
# Sigmoid Curve when k=50.

# %% [markdown]
# <H1> CODE</H1>

# %%
import math
import numpy as np

def sigmoid(x):
    """
    
    :param x: float
    :return: float
    """
    s = 1.0/(1.0+math.exp(-x))
    return s

print (sigmoid(np.float(50)))
# Out:
# 1.0
