# %% [markdown]
# # There are several activation functions <br>
#
# 1. Identity<br>
# 2. Sigmoid<br>
# 3. Binary Step<br>
# 4. Tanh<br>
# 5. Arc Tan<br>
# 6. RELU<br>
# 7. Leaky RELU<br>
# 8. SoftMax<br>

# %%
import math
from  IPython.display import Image
import os

# CONSOLIDATED REPRESENTATION OF FUNCTIONS

Image(filename=os.getcwd()+"/images/activaton_consolidated.png")

# %%
# CONSOLIDATED REPRESENTATION OF CURVES

Image(filename=os.getcwd()+"/images/curves.png")

# %%
# Sigmoid Curve representation

Image(filename=os.getcwd()+"/images/sigmoid_activation.png")

# %%
# Q.Write a function which implements sigmoid function

def sigmoid(x):
    """
    :param x: numpy float
    :return: numpy float
    """
    s= 1/(1+math.exp(x))
    return s

# %%
# RELU/LEAKY RELU representation

Image(filename=os.getcwd()+"/images/leaky_relu.png")

# %%
# Q.Write a function which implements LEAKY RELU function

def leaky_RELU(x):
    """    
    :param x: numpy float
    :return: numpy float
    """
    if x< 0:
        return 0.01*x
    else:
        return x

# %%
# TANH curve representation

Image(filename=os.getcwd()+"/images/tanh.png")

# %%
# Q.Write a function which implements TANH function

def tanh(x):
    """
    :param x: numpy float
    :return: numpy float
    """
    t = 2 / (1 + 2*math.exp(x))
    return t

# %%
# RELU curve representation

Image(filename=os.getcwd()+"/images/relu.png")

# %%
# Q.Write a function which implements RELU function

def RELU(x):
    """
    :param x: numpy float
    :return: numpy float
    """
    if x<0:
        return 0
    else:
        return x

# %%
# IDENTITY curve representation

Image(filename=os.getcwd()+"/images/identity.png")

# %%
# Q.Write a function which implements IDENTITY function

def identity(x):
    """
    :param x: numpy float
    :return: numpy float
    """
    return x
